# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Carregando base de dados...")
df = pd.read_csv("ZIKA_BR_2018_2026_UNIFICADO.csv", low_memory=False)
print(f"Base carregada! Total de registros: {len(df)}")

display(df.describe())
# Out:
# Carregando base de dados...
# Base carregada! Total de registros: 236398
#          ano_arquivo    TP_NOT  CS_SUSPEIT        SEM_NOT         NU_ANO  \
# count  236398.000000  236398.0         0.0  236398.000000  236398.000000
# mean     2021.917893       2.0         NaN  202211.177870    2021.919001
# std         2.262070       0.0         NaN     624.738277       2.262331
# min      2018.000000       2.0         NaN    1805.000000    2018.000000
# 25%      2020.000000       2.0         NaN  202016.000000    2020.000000
# 50%      2022.000000       2.0         NaN  202228.000000    2022.000000
# 75%      2024.000000       2.0         NaN  202411.000000    2024.000000
# max      2026.000000       2.0         NaN  202617.000000    2026.000000
#
#            SG_UF_NOT     ID_MUNICIP     ID_REGIONA        SEM_PRI  \
# count  236398.000000  236398.000000  191340.000000  236398.000000
# mean       29.391852  295001.471485    5460.816959  202209.406488
# std        10.596286  106059.135137   10051.564809     626.563107
# min        11.000000  110001.000000    1331.000000    1804.000000
# 25%        24.000000  240310.000000    1416.000000  202015.000000
# 50%        29.000000  290070.000000    1497.000000  202227.000000
# 75%        32.000000  320530.000000    1800.000000  202410.000000
# max        53.000000  530010.000000   32004.000000  202616.000000
#
#           NU_IDADE_N  ...     CLASSI_FIN       CRITERIO     TPAUTOCTO  \
# count  236398.000000  ...  230982.000000  205736.000000  57240.000000
# mean     3987.159989  ...       2.503797       1.313309      1.255416
# std       267.440494  ...       1.908844       0.467701      0.642978
# min      1001.000000  ...       0.000000       0.000000      1.000000
# 25%      4018.000000  ...       2.000000       1.000000      1.000000
# 50%      4030.000000  ...       2.000000       1.000000      1.000000
# 75%      4044.000000  ...       2.000000       2.000000      1.000000
# max      4119.000000  ...       8.000000       2.000000      3.000000
#
#             COMUNINF    DOENCA_TRA       EVOLUCAO     CS_FLXRET     FLXRECEBI  \
# count   50565.000000  52494.000000  193457.000000  51084.000000  51084.000000
# mean   163445.914823      2.225988       2.022294      0.182660      1.999589
# std    171016.427548      2.454719       2.683539      0.681665      0.020271
# min         0.000000      0.000000       0.000000      0.000000      1.000000
# 25%         0.000000      1.000000       1.000000      0.000000      2.000000
# 50%    150600.000000      2.000000       1.000000      0.000000      2.000000
# 75%    290340.000000      2.000000       1.000000      0.000000      2.000000
# max    539924.000000      9.000000       9.000000      5.000000      2.000000
#
#          ID_UNIDADE       ANO_NASC
# count  1.853140e+05  183682.000000
# mean   3.983926e+06    1990.019109
# std    2.684082e+06      19.322880
# min    1.700000e+01    1904.000000
# 25%    2.403595e+06    1977.000000
# 50%    2.607573e+06    1992.000000
# 75%    6.439837e+06    2004.000000
# max    9.999396e+06    2026.000000
#
# [8 rows x 28 columns]

# %%
print("Limpando e transformando dados...")

# 1. Datas
date_cols = ['DT_NOTIFIC', 'DT_SIN_PRI', 'DT_OBITO', 'DT_ENCERRA']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# 2. Categóricas (Mapeando '9' para 'Não Informado')
raca_map = {1.0: 'Branca', 2.0: 'Preta', 3.0: 'Amarela', 4.0: 'Parda', 5.0: 'Indígena', 9.0: 'Não Informado'}
df['CS_RACA_STR'] = df['CS_RACA'].map(raca_map).fillna('Não Informado')

sexo_map = {'M': 'Masculino', 'F': 'Feminino', 'I': 'Não Informado'}
df['CS_SEXO_STR'] = df['CS_SEXO'].map(sexo_map).fillna('Não Informado')

gestant_map = {1.0: '1º trim', 2.0: '2º trim', 3.0: '3º trim', 4.0: 'Ignorada', 5.0: 'Não', 6.0: 'Não se aplica', 9.0: 'Não Informado'}
df['CS_GESTANT_STR'] = df['CS_GESTANT'].map(gestant_map).fillna('Não Informado')

evolucao_map = {0.0: 'Em investigação', 1.0: 'Cura', 2.0: 'Óbito pelo agravo', 3.0: 'Óbito outra causa', 9.0: 'Não Informado'}
df['EVOLUCAO_STR'] = df['EVOLUCAO'].map(evolucao_map).fillna('Não Informado')

classi_map = {0.0: 'Descartado', 1.0: 'Confirmado', 2.0: 'Em investigação', 8.0: 'Inconclusivo'}
df['CLASSI_FIN_STR'] = df['CLASSI_FIN'].map(classi_map).fillna('Não Informado')

# 3. Decodificação de Idade
# IMPORTANTE: alinhado à função SQL fn_decodifica_idade_anos.
# Unidade 4 = anos -> retorna o valor. Unidades 1/2/3 (hora/dia/mês) = menos de
# um ano -> retorna 0 (cai na faixa '0-4 anos' na pirâmide etária do dashboard).
# Mantém SQL e Python produzindo os MESMOS números por faixa etária.
def decode_age(age_code):
    if pd.isna(age_code):
        return np.nan
    try:
        age_str = str(int(age_code)).zfill(4)
        unit = int(age_str[0])
        value = int(age_str[1:])
        if unit == 4:
            return value          # Anos
        elif unit in (1, 2, 3):
            return 0              # Hora/dia/mês = menos de 1 ano (igual ao SQL)
        else:
            return np.nan
    except:
        return np.nan

df['IDADE_ANOS'] = df['NU_IDADE_N'].apply(decode_age)

# Sanitiza idades implausíveis (erros de digitação no SINAN, ex.: 200+ anos)
df.loc[(df['IDADE_ANOS'] < 0) | (df['IDADE_ANOS'] > 120), 'IDADE_ANOS'] = np.nan

print("Transformação concluída!")
df[['DT_SIN_PRI', 'CS_RACA_STR', 'IDADE_ANOS', 'CS_GESTANT_STR']].head()
# Out:
# Limpando e transformando dados...
# Transformação concluída!
#   DT_SIN_PRI CS_RACA_STR  IDADE_ANOS CS_GESTANT_STR
# 0 2017-12-28       Parda        34.0            Não
# 1 2017-12-29       Parda        34.0  Não se aplica
# 2 2017-12-31       Parda         3.0  Não se aplica
# 3 2018-01-01       Parda        14.0            Não
# 4 2017-12-31       Preta        31.0  Não se aplica

# %% [markdown]
# ## Deduplicação de notificações
#
# Aplica a **mesma** regra do ETL para que os números desta análise batam com o banco. A base não tem identificador de pessoa (sem `NU_CNS`), então a duplicidade é de **notificação**, detectada por uma chave composta. Mantém-se 1 representante por grupo: o mais completo; no empate, a digitação mais antiga (`DT_DIGITA`); por fim, o menor índice.

# %%
# Deduplicação — idêntica à do ETL (etl.py), para coerência com o banco.
# Chave composta de notificação (sem identificador de pessoa):
CHAVE_DUP = ['ID_AGRAVO', 'DT_SIN_PRI', 'NU_IDADE_N', 'CS_SEXO', 'ID_MN_RESI', 'ID_MUNICIP']

n_antes = len(df)
_d = df.copy()
_d['_idx'] = np.arange(n_antes)
_d['_completude'] = _d.notna().sum(axis=1)
_d['_dt_digita'] = pd.to_datetime(_d.get('DT_DIGITA'), errors='coerce')

# NDUPLIC_N > 1 (marcação do próprio SINAN) rebaixa o registro para ser o descartado
_nd = pd.to_numeric(_d.get('NDUPLIC_N'), errors='coerce')
_d['_marcado_sinan'] = _nd.notna() & (_nd > 1)

# Ordena para que o 1º de cada grupo seja o representante a manter
_d = _d.sort_values(
    by=['_marcado_sinan', '_completude', '_dt_digita', '_idx'],
    ascending=[True, False, True, True],
    na_position='last'
)

# Chave como string (NaN vira token fixo para agrupar de forma consistente)
_chave = _d[CHAVE_DUP].astype(str).where(_d[CHAVE_DUP].notna(), '\u2205').agg('|'.join, axis=1)
_eh_primeiro = ~_chave.duplicated(keep='first')

n_dup = int((~_eh_primeiro).sum())

# Mantém só os representantes e remove as colunas auxiliares
df = (_d[_eh_primeiro]
      .sort_values('_idx')
      .drop(columns=['_idx', '_completude', '_dt_digita', '_marcado_sinan'])
      .reset_index(drop=True))

print(f"Registros antes da deduplicação:  {n_antes}")
print(f"Duplicatas removidas:             {n_dup}")
print(f"Registros após deduplicação:      {len(df)}")
print(f"Proporção de duplicatas:          {100*n_dup/n_antes:.2f}%")
# Out:
# Registros antes da deduplicação:  236398
# Duplicatas removidas:             5639
# Registros após deduplicação:      230759
# Proporção de duplicatas:          2.39%

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
import pandas as pd

# --- MAPEAMENTO DE CÓDIGO IBGE → SIGLA ---
ibge_para_uf = {
    11:'RO', 12:'AC', 13:'AM', 14:'RR', 15:'PA', 16:'AP', 17:'TO',
    21:'MA', 22:'PI', 23:'CE', 24:'RN', 25:'PB', 26:'PE', 27:'AL',
    28:'SE', 29:'BA', 31:'MG', 32:'ES', 33:'RJ', 35:'SP',
    41:'PR', 42:'SC', 43:'RS',
    50:'MS', 51:'MT', 52:'GO', 53:'DF'
}

df['ANO_MES_DT'] = df['DT_SIN_PRI'].dt.to_period('M').dt.to_timestamp()
df = df[df['ANO_MES_DT'] >= '2018-01-01']

df['UF_SIGLA'] = df['SG_UF_NOT'].map(ibge_para_uf).fillna(df['SG_UF_NOT'].astype(str))

top_5_ufs = df['UF_SIGLA'].value_counts().nlargest(5).index.tolist()

df['UF_AGRUPADA'] = df['UF_SIGLA'].apply(lambda x: x if x in top_5_ufs else 'Outros Estados')

uf_ts = df.groupby(['ANO_MES_DT', 'UF_AGRUPADA']).size().unstack(fill_value=0)

cols = ['Outros Estados'] + top_5_ufs
cols = [c for c in cols if c in uf_ts.columns]
uf_ts = uf_ts[cols]

uf_ts_smooth = uf_ts.rolling(window=3, min_periods=1).mean()

cores = ['#C8C5BC', '#1D9E75', '#378ADD', '#D4537E', '#EF9F27', '#E24B4A'][:len(cols)]

fig, ax = plt.subplots(figsize=(20, 8), dpi=120)

uf_ts_smooth.plot(
    kind='area', stacked=True, ax=ax,
    color=cores, alpha=0.82, linewidth=1.0
)

ax.set_title('Curva Epidêmica de Zika (2018–2026): Composição por UF',
             fontsize=16, fontweight='bold', pad=14)
ax.set_xlabel('Período dos Primeiros Sintomas', fontsize=12, labelpad=8)
ax.set_ylabel('Casos Notificados (suavizados)', fontsize=12, labelpad=8)

# --- EIXO X COM ANOS GARANTIDOS ---
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.set_xlim(
    pd.Timestamp('2018-01-01'),
    df['ANO_MES_DT'].max() + pd.DateOffset(months=1)
)

for label in ax.get_xticklabels():
    label.set_visible(True)
    label.set_fontsize(11)
    label.set_rotation(0)
    label.set_ha('center')

ax.yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f'{x/1000:.0f}k' if x >= 1000 else f'{int(x)}')
)
ax.tick_params(axis='y', labelsize=11)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1],
          title='UF', title_fontsize=11, fontsize=10,
          loc='upper left', frameon=True, framealpha=0.9, edgecolor='#cccccc')

ax.grid(axis='y', linestyle='--', alpha=0.35, color='gray')
ax.grid(axis='x', visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_alpha(0.3)
ax.spines['bottom'].set_alpha(0.3)

plt.tight_layout()
plt.show()

# %%
# Gráfico de barras empilhadas por UF e Classificação Final
uf_class_counts = df.groupby(['SG_UF_NOT', 'CLASSI_FIN_STR']).size().unstack(fill_value=0)

# Ordenar pelas UFs com mais casos gerais
uf_class_counts['TOTAL'] = uf_class_counts.sum(axis=1)
uf_class_counts = uf_class_counts.sort_values('TOTAL', ascending=False).drop('TOTAL', axis=1)

uf_class_counts.plot(kind='bar', stacked=True, figsize=(16, 7), colormap='Set2')
plt.title('Casos por Unidade Federativa e Situação (Classificação Final)', fontsize=16)
plt.xlabel('Unidade Federativa (UF)')
plt.ylabel('Total de Notificações')
plt.legend(title='Classificação Final')
plt.xticks(rotation=0)
plt.show()

# %%
# Filtrar apenas mulheres para analisar a variável Gestante
mulheres = df[df['CS_SEXO'] == 'F']

# Excluir 'Não se aplica' (já que estamos olhando só mulheres)
ordem_gest = ['1º trim', '2º trim', '3º trim', 'Ignorada', 'Não', 'Não Informado']
gestantes = mulheres[mulheres['CS_GESTANT_STR'].isin(ordem_gest)]

plt.figure(figsize=(14, 6))
# hue + legend=False evita o FutureWarning do seaborn (palette sem hue)
sns.countplot(data=gestantes, x='CS_GESTANT_STR', order=ordem_gest,
              hue='CS_GESTANT_STR', palette='coolwarm', legend=False)
plt.title('Situação Gestacional das Mulheres Notificadas com Zika', fontsize=16)
plt.xlabel('Trimestre de Gestação (ou Não Gestante)')
plt.ylabel('Número de Notificações')
plt.show()

print("\n--- ATENÇÃO EPIDEMIOLÓGICA ---")
total_gestantes = len(gestantes[gestantes['CS_GESTANT_STR'].isin(['1º trim', '2º trim', '3º trim'])])
print(f"Total de Gestantes Notificadas: {total_gestantes} (Requerem acompanhamento para Síndrome Congênita)")
# Out:
# --- ATENÇÃO EPIDEMIOLÓGICA ---
# Total de Gestantes Notificadas: 23374 (Requerem acompanhamento para Síndrome Congênita)

# %%
# Calcular a diferença em dias entre Sintoma e Notificação
df['LATENCIA_DIAS'] = (df['DT_NOTIFIC'] - df['DT_SIN_PRI']).dt.days

# RECORTE para visualização: 0 a 100 dias.
# Obs.: o SINAN recebe notificações tardias por anos (correções retrospectivas),
# então este gráfico mostra a JANELA TÍPICA, não o universo completo de latências.
latencia_valida = df[(df['LATENCIA_DIAS'] >= 0) & (df['LATENCIA_DIAS'] <= 100)]
pct_recorte = 100 * len(latencia_valida) / df['LATENCIA_DIAS'].notna().sum()

plt.figure(figsize=(16, 6))
sns.histplot(latencia_valida['LATENCIA_DIAS'].dropna(), bins=50, kde=True, color='purple')
plt.title(f'Latência de Notificação (0–100 dias; representa {pct_recorte:.1f}% das fichas com data)', fontsize=15)
plt.xlabel('Dias de Atraso (Latência entre 1º Sintoma e Notificação)')
plt.ylabel('Frequência')
plt.axvline(latencia_valida['LATENCIA_DIAS'].median(), color='red', linestyle='--',
            label=f"Mediana: {latencia_valida['LATENCIA_DIAS'].median():.0f} dias")
plt.legend()
plt.show()

# %%
# Boxplot de idade por UF (idades implausíveis já foram removidas na limpeza)
ordem_uf = df['SG_UF_NOT'].value_counts().index
plt.figure(figsize=(16, 7))
sns.boxplot(data=df, x='SG_UF_NOT', y='IDADE_ANOS', order=ordem_uf,
            hue='SG_UF_NOT', palette='pastel', legend=False)
plt.title('Distribuição de Idade dos Notificados por UF', fontsize=16)
plt.xlabel('Unidade Federativa (UF) - Ordenada por Volume')
plt.ylabel('Idade (Anos)')
plt.show()

# %%
# Taxa de campos "Não Informado" para Raça/Cor por UF
raca_ninf = df[df['CS_RACA_STR'] == 'Não Informado'].groupby('SG_UF_NOT').size()
total_uf = df.groupby('SG_UF_NOT').size()

taxa_ninf = (raca_ninf / total_uf * 100).fillna(0).sort_values(ascending=False)

plt.figure(figsize=(16, 6))
sns.barplot(x=taxa_ninf.index, y=taxa_ninf.values,
            hue=taxa_ninf.index, palette='Reds_r', legend=False)
plt.title('% de Fichas com Raça/Cor "Não Informada" por UF', fontsize=16)
plt.xlabel('UF')
plt.ylabel('Porcentagem (%)')
plt.axhline(taxa_ninf.mean(), color='red', linestyle='--', label=f'Média Nacional: {taxa_ninf.mean():.1f}%')
plt.legend()
plt.show()

# %%
# Ver as informações gerais das colunas (quais são números, quais são textos)
df.info()

# Ver estatísticas básicas das colunas numéricas (média, mínimo, máximo)
df.describe()

# Ver quantos casos estão marcados como duplicados no sistema
df['NDUPLIC_N'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# Index: 230181 entries, 3 to 230758
# Data columns (total 53 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   arquivo_origem  230181 non-null  str
#  1   ano_arquivo     230181 non-null  int64
#  2   TP_NOT          230181 non-null  int64
#  3   ID_AGRAVO       230181 non-null  str
#  4   CS_SUSPEIT      0 non-null       float64
#  5   DT_NOTIFIC      230181 non-null  datetime64[us]
#  6   SEM_NOT         230181 non-null  int64
#  7   NU_ANO          230181 non-null  int64
#  8   SG_UF_NOT       230181 non-null  int64
#  9   ID_MUNICIP      230181 non-null  int64
#  10  ID_REGIONA      186445 non-null  float64
#  11  DT_SIN_PRI      230181 non-null  datetime64[us]
#  12  SEM_PRI         230181 non-null  int64
#  13  NU_IDADE_N      230181 non-null  int64
#  14  CS_SEXO         230181 non-null  str
#  15  CS_GESTANT      230176 non-null  float64
#  16  CS_RACA         230180 non-null  float64
#  17  CS_ESCOL_N      206027 non-null  float64
#  18  SG_UF           230130 non-null  float64
#  19  ID_MN_RESI      230130 non-null  float64
#  20  ID_RG_RESI      170077 non-null  str
#  21  ID_PAIS         230181 non-null  int64
#  22  NDUPLIC_N       23488 non-null   float64
#  23  IN_VINCULA      23002 non-null   float64
#  24  DT_INVEST       214893 non-null  str
#  25  ID_OCUPA_N      6612 non-null    str
#  26  CLASSI_FIN      224863 non-null  float64
#  27  CRITERIO        200444 non-null  float64
#  28  TPAUTOCTO       55801 non-null   float64
#  29  COUFINF         28827 non-null   str
#  30  COPAISINF       230181 non-null  str
#  31  COMUNINF        49316 non-null   float64
#  32  DOENCA_TRA      51120 non-null   float64
#  33  EVOLUCAO        188578 non-null  float64
#  34  DT_OBITO        983 non-null     datetime64[us]
#  35  DT_ENCERRA      224562 non-null  datetime64[us]
#  36  CS_FLXRET       49472 non-null   float64
#  37  FLXRECEBI       49472 non-null   float64
#  38  TP_SISTEMA      126946 non-null  str
#  39  TPUNINOT        6610 non-null    str
#  40  ID_UNIDADE      180709 non-null  float64
#  41  ANO_NASC        179167 non-null  float64
#  42  DT_DIGITA       180709 non-null  str
#  43  CS_RACA_STR     230181 non-null  str
#  44  CS_SEXO_STR     230181 non-null  str
#  45  CS_GESTANT_STR  230181 non-null  str
#  46  EVOLUCAO_STR    230181 non-null  str
#  47  CLASSI_FIN_STR  230181 non-null  str
#  48  IDADE_ANOS      230181 non-null  float64
#  49  ANO_MES_DT      230181 non-null  datetime64[us]
#  50  UF_SIGLA        230181 non-null  str
#  51  UF_AGRUPADA     230181 non-null  str
#  52  LATENCIA_DIAS   230181 non-null  int64
# dtypes: datetime64[us](5), float64(20), int64(10), str(18)
# memory usage: 94.8 MB
# NDUPLIC_N
# 0.0    23009
# 1.0      470
# 2.0        9
# Name: count, dtype: int64
